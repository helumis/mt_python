# %%
""""
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin

BASE_URL = "https://zh.wikipedia.org"

def list_wiki_links(url, ndisplay=10):
    """抓取指定條目下的 wiki 連結，列出前 ndisplay 筆 (不重複)"""
    res = requests.get(url, headers={"User-Agent": "Mozilla/5.0"}, timeout=5)
    res.raise_for_status()
    soup = BeautifulSoup(res.text, "html.parser")

    links = {}
    for a in soup.select("#mw-content-text a[href]"):
        href = a.get("href")
        title = a.get_text(strip=True)
        if not href or not title:
            continue
        if href.startswith("/wiki/") or href.startswith("/zh-tw/"):
            if not any(prefix in href for prefix in [":", "#"]):
                full_url = urljoin(BASE_URL, href)
                if full_url not in links:  # 避免重複
                    links[full_url] = title

    # 顯示前 ndisplay 筆
    for i, (link, title) in enumerate(links.items()):
        if i >= ndisplay:
            break
        print(f"{i+1}. {title} → {link}")

if __name__ == "__main__":
    list_wiki_links("https://zh.wikipedia.org/zh-tw/淡江大學", ndisplay=10)

""""
# Out:
# 1. 臺北縣 → https://zh.wikipedia.org/wiki/%E8%87%BA%E5%8C%97%E7%B8%A3
# 2. TKU → https://zh.wikipedia.org/wiki/TKU
# 3. 校訓 → https://zh.wikipedia.org/wiki/%E6%A0%A1%E8%AE%AD
# 4. 居正 → https://zh.wikipedia.org/wiki/%E5%B1%85%E6%AD%A3
# 5. 學校代碼 → https://zh.wikipedia.org/wiki/%E5%AD%B8%E6%A0%A1%E4%BB%A3%E7%A2%BC
# 6. 私立 → https://zh.wikipedia.org/wiki/%E7%A7%81%E7%AB%8B%E5%A4%A7%E5%AD%B8
# 7. 綜合大學 → https://zh.wikipedia.org/wiki/%E7%B6%9C%E5%90%88%E5%A4%A7%E5%AD%B8
# 8. 張家宜 → https://zh.wikipedia.org/wiki/%E5%BC%B5%E5%AE%B6%E5%AE%9C
# 9. 校長 → https://zh.wikipedia.org/wiki/%E6%A0%A1%E9%95%BF
# 10. 葛煥昭 → https://zh.wikipedia.org/wiki/%E8%91%9B%E7%85%A5%E6%98%AD

# %%
#conda install requests beautifulsoup4 -y
# Out:
# Jupyter detected...
# 2 channel Terms of Service accepted
# doneieving notices: -
# Channels:
#  - defaults
# Platform: osx-arm64
# doneecting package metadata (repodata.json): /
# doneing environment: |
#
# ## Package Plan ##
#
#   environment location: /opt/anaconda3
#
#   added / updated specs:
#     - beautifulsoup4
#     - requests
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     beautifulsoup4-4.13.5      |  py313hca03da5_0         264 KB
#     certifi-2025.10.5          |  py313hca03da5_0         157 KB
#     openssl-3.0.18             |       h9b4081a_0         3.1 MB
#     ------------------------------------------------------------
#                                            Total:         3.5 MB
#
# The following packages will be UPDATED:
#
#   beautifulsoup4                     4.12.3-py313hca03da5_0 --> 4.13.5-py313hca03da5_0
#   certifi                          2025.8.3-py313hca03da5_0 --> 2025.10.5-py313hca03da5_0
#   openssl                                 3.0.17-h4ee41c1_0 --> 3.0.18-h9b4081a_0
#
#
#
# Downloading and Extracting Packages:
# openssl-3.0.18       | 3.1 MB    |                                       |   0%
# beautifulsoup4-4.13. | 264 KB    |                                       |   0%
#
# certifi-2025.10.5    | 157 KB    |                                       |   0%
#
# openssl-3.0.18       | 3.1 MB    | 1                                     |   1%
#
# certifi-2025.10.5    | 157 KB    | ##################################### | 100%
#
# openssl-3.0.18       | 3.1 MB    | ###########8                          |  32%
# openssl-3.0.18       | 3.1 MB    | ###################4                  |  52%
# openssl-3.0.18       | 3.1 MB    | ##################################### | 100%
# beautifulsoup4-4.13. | 264 KB    | ##########################8           |  73%
# beautifulsoup4-4.13. | 264 KB    | ##################################### | 100%
#
#
#
#
# donearing transaction: |
# donefying transaction: -
# doneuting transaction: /
#
# Note: you may need to restart the kernel to use updated packages.

# %%
"""""
User-Agent: *
Disallow: /m/
Disallow: /me/
Disallow: /@me$
Disallow: /@me/
Disallow: /*/edit$
Disallow: /*/*/edit$
Disallow: /media/
Disallow: /p/*/share
Disallow: /r/
Disallow: /trending
Disallow: /search?q$
Disallow: /search?q=
Disallow: /*/search?q=
Disallow: /*/search/*?q=
Disallow: /*/*source=
Allow: /_/api/users/*/meta
Allow: /_/api/users/*/profile/stream
Allow: /_/api/posts/*/responses
Allow: /_/api/posts/*/responsesStream
Allow: /_/api/posts/*/related
User-Agent: Amazonbot
User-Agent: Applebot-Extended
User-Agent: Bytespider
User-Agent: ClaudeBot
User-Agent: FacebookBot
User-Agent: GoogleOther
User-Agent: GPTBot
User-Agent: meta-externalagent
Disallow: /
Allow: /about
Allow: /business
Allow: /earn
Allow: /gift
Allow: /membership
Allow: /partner-program
Allow: /verified-authors
Sitemap: https://netflixtechblog.com/sitemap/sitemap.xml
License: https://medium.com/license.xml
"""""

import requests
from bs4 import BeautifulSoup
import urllib3
import pandas as pd

# 忽略 SSL 警告
urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)

# 取得 sitemap
sitemap_url = "https://netflixtechblog.com/sitemap/sitemap.xml"
response = requests.get(sitemap_url, verify=False)
soup = BeautifulSoup(response.content, "lxml-xml")

# 解析 <url> 標籤
urls = []
for url_tag in soup.find_all("url"):
    loc = url_tag.find("loc").text
    lastmod_tag = url_tag.find("lastmod")
    lastmod = lastmod_tag.text if lastmod_tag else None
    changefreq_tag = url_tag.find("changefreq")
    changefreq = changefreq_tag.text if changefreq_tag else None
    priority_tag = url_tag.find("priority")
    priority = priority_tag.text if priority_tag else None
    urls.append({
        "loc": loc,
        "lastmod": lastmod,
        "changefreq": changefreq,
        "priority": priority
    })

# 轉成 DataFrame
df = pd.DataFrame(urls)

# 存 CSV
df.to_csv("netflix_techblog_sitemap.csv", index=False, encoding="utf-8-sig")

print("CSV 檔案已儲存！")
print(df.head(10))
# Out:
# CSV 檔案已儲存！
#                                                  loc     lastmod changefreq  \
# 0       https://netflixtechblog.com/tagged/benchmark  2016-09-01    monthly
# 1           https://netflixtechblog.com/tagged/build  2016-03-09    monthly
# 2    https://netflixtechblog.com/tagged/chaos-monkey  2017-07-26    monthly
# 3     https://netflixtechblog.com/tagged/simian-army  2017-03-13    monthly
# 4  https://netflixtechblog.com/tagged/netflixsecu...  2019-11-22    monthly
# 5             https://netflixtechblog.com/tagged/isp  2016-08-09    monthly
# 6  https://netflixtechblog.com/tagged/streaming-v...  2017-12-20    monthly
# 7           https://netflixtechblog.com/tagged/nosql  2015-01-27    monthly
# 8           https://netflixtechblog.com/tagged/cloud  2023-08-29    monthly
# 9             https://netflixtechblog.com/tagged/api  2021-09-15    monthly
#
#   priority
# 0      1.0
# 1      1.0
# 2      1.0
# 3      1.0
# 4      1.0
# 5      1.0
# 6      1.0
# 7      1.0
# 8      1.0
# 9      1.0

# %%
import pandas as pd

# 讀取原始 CSV
df = pd.read_csv("netflix_techblog_sitemap.csv", encoding="utf-8-sig")

# 1. 去掉網域（https://netflixtechblog.com 或 https://netflixtechblog.com/）
df["loc"] = df["loc"].str.replace(r"^https://netflixtechblog.com/?", "", regex=True)

# 2. 刪掉空白 loc 的觀察值
df = df[df["loc"].str.strip() != ""]

# 3. 計算每個 loc 中 '/' 的數量，找最大層級
df["slash_count"] = df["loc"].str.count("/")
max_slash = df["slash_count"].max()
print(f"最大層級數: {max_slash}")

# 4. 拆分 loc 為 level 欄位
split_cols = [f"level_{i+1}" for i in range(max_slash + 1)]
df[split_cols] = df["loc"].str.split("/", expand=True)

# 5. 移除暫時的 slash_count
df = df.drop(columns=["slash_count"])

# 6. 保留最後需要的欄位順序（loc、lastmod、level_1、level_2…）
cols = ["loc", "lastmod"] + split_cols
df = df[cols]

# 7. 存成 CSV
df.to_csv("netflix_techblog_sitemap_split_clean.csv", index=False, encoding="utf-8-sig")

print("已清理並拆層級，存成 netflix_techblog_sitemap_split_clean.csv")
print(df.head(10))
# Out:
# 最大層級數: 1
# 已清理並拆層級，存成 netflix_techblog_sitemap_split_clean.csv
#                                                  loc     lastmod  \
# 0  fm-intent-predicting-user-session-intent-with-...  2025-05-21
# 1  unbundling-data-science-workflows-with-metaflo...  2020-07-29
# 2                      tagged/developer-productivity  2021-04-26
# 3                             tagged/neural-networks  2022-11-14
# 4  machine-learning-for-a-better-developer-experi...  2020-07-28
# 5  rebuilding-netflix-video-processing-pipeline-w...  2024-01-10
# 6                                     tagged/network  2024-04-24
# 7                                         tagged/tcp  2024-04-24
# 8                                      tagged/kernel  2024-04-24
# 9  investigation-of-a-cross-regional-network-perf...  2024-04-24
#
#                                              level_1                 level_2
# 0  fm-intent-predicting-user-session-intent-with-...                    None
# 1  unbundling-data-science-workflows-with-metaflo...                    None
# 2                                             tagged  developer-productivity
# 3                                             tagged         neural-networks
# 4  machine-learning-for-a-better-developer-experi...                    None
# 5  rebuilding-netflix-video-processing-pipeline-w...                    None
# 6                                             tagged                 network
# 7                                             tagged                     tcp
# 8                                             tagged                  kernel
# 9  investigation-of-a-cross-regional-network-perf...                    None

# %%
import pandas as pd

# 讀取剛剛清理後的檔案
df = pd.read_csv("netflix_techblog_sitemap_split_clean.csv", encoding="utf-8-sig")

# 檢查欄位
print(df.columns)

# 拆分成兩個 DataFrame
df_tagged = df[df["level_1"] == "tagged"].copy()
df_non_tagged = df[df["level_1"] != "tagged"].copy()

# 分別輸出成 CSV
df_tagged.to_csv("netflix_techblog_tagged.csv", index=False, encoding="utf-8-sig")
df_non_tagged.to_csv("netflix_techblog_non_tagged.csv", index=False, encoding="utf-8-sig")

print(f"已拆分完成：")
print(f"  tagged 共有 {len(df_tagged)} 筆")
print(f"  非 tagged 共有 {len(df_non_tagged)} 筆")
# Out:
# Index(['loc', 'lastmod', 'level_1', 'level_2'], dtype='object')
# 已拆分完成：
#   tagged 共有 742 筆
#   非 tagged 共有 214 筆

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import time
import random
import urllib3

# 關閉 SSL 驗證警告
urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)

# === 1. 匯入 CSV ===
df_tags = pd.read_csv("netflix_techblog_tagged.csv")
df_tags["tag_url"] = "https://netflixtechblog.com/" + df_tags["loc"]
df_tags["tag"] = df_tags["level_2"]

# 用 dict 暫存文章 -> tags
articles_dict = {}

# === 2. 定義爬蟲函數 ===
def fetch_tag_articles(tag_url, tag):
    """從單一 tag 頁面提取所有 data-href"""
    headers = {
        "User-Agent": random.choice([
            "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 Chrome/120.0.0.0 Safari/537.36",
            "Mozilla/5.0 (Macintosh; Intel Mac OS X 13_0) AppleWebKit/537.36 Chrome/120.0.0.0 Safari/537.36"
        ]),
        "Accept-Language": "en-US,en;q=0.9"
    }

    print(f"爬取中: {tag_url}")
    try:
        resp = requests.get(tag_url, headers=headers, verify=False, timeout=10)
    except Exception as e:
        print(f"❌ {tag_url} 請求失敗: {e}")
        return []

    if resp.status_code != 200:
        print(f"⚠️ {tag_url} 狀態碼 {resp.status_code}")
        return []

    soup = BeautifulSoup(resp.text, "html.parser")
    articles = []
    for card in soup.select("div[data-href]"):
        href = card.get("data-href")
        if href:
            articles.append(href.strip())
    time.sleep(0.2)  # 隨機延遲
    return articles

# === 3. 主爬蟲迴圈 ===
for i, row in df_tags.iterrows():
    tag = row["tag"]
    tag_url = row["tag_url"]
    try:
        article_urls = fetch_tag_articles(tag_url, tag)
        for url in article_urls:
            if url not in articles_dict:
                articles_dict[url] = [tag]  # 新文章 -> 新 list
            else:
                articles_dict[url].append(tag)  # 已有文章 -> append tag
        print(f"✅ {tag} 共抓到 {len(article_urls)} 篇文章")
    except Exception as e:
        print(f"⚠️ {tag} 發生錯誤: {e}")

# === 4. 轉成 DataFrame ===
articles_df = pd.DataFrame([
    {"article_url": url, "tags": ",".join(tags)}
    for url, tags in articles_dict.items()
])

# === 5. 儲存 CSV ===
articles_df.to_csv("netflix_techblog_articles.csv", index=False, encoding="utf-8-sig")
print(f"✅ 完成！共 {len(articles_df)} 筆文章連結。")
# Out:
# 爬取中: https://netflixtechblog.com/tagged/developer-productivity
# ✅ developer-productivity 共抓到 2 篇文章
# 爬取中: https://netflixtechblog.com/tagged/neural-networks
# ✅ neural-networks 共抓到 2 篇文章
# 爬取中: https://netflixtechblog.com/tagged/network
# ✅ network 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/tcp
# ✅ tcp 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/kernel
# ✅ kernel 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/artificial-intelligence
# ✅ artificial-intelligence 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/payment-processing
# ✅ payment-processing 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/ml-explainability
# ✅ ml-explainability 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/ml-observability
# ✅ ml-observability 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/system-design-concepts
# ✅ system-design-concepts 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/foundation-models
# ✅ foundation-models 共抓到 2 篇文章
# 爬取中: https://netflixtechblog.com/tagged/intelligibility
# ✅ intelligibility 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/dialogue
# ✅ dialogue 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/big-data-platform
# ✅ big-data-platform 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/memory-management
# ✅ memory-management 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/machine-learning-platform
# ✅ machine-learning-platform 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/human-centric-design
# ✅ human-centric-design 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/ai
# ✅ ai 共抓到 4 篇文章
# 爬取中: https://netflixtechblog.com/tagged/jvm
# ✅ jvm 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/garbage-collection
# ✅ garbage-collection 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/rule-based-classification
# ✅ rule-based-classification 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/operational-efficiency
# ✅ operational-efficiency 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/cost-efficiency
# ✅ cost-efficiency 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/rdf
# ✅ rdf 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/knowledge-management
# ✅ knowledge-management 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/data-catalog
# ✅ data-catalog 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/eventing
# ✅ eventing 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/ambiguity
# ✅ ambiguity 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/staff-engineering
# ✅ staff-engineering 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/rust
# ✅ rust 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/build
# ✅ build 共抓到 3 篇文章
# 爬取中: https://netflixtechblog.com/tagged/chaos-monkey
# ✅ chaos-monkey 共抓到 8 篇文章
# 爬取中: https://netflixtechblog.com/tagged/simian-army
# ✅ simian-army 共抓到 7 篇文章
# 爬取中: https://netflixtechblog.com/tagged/netflixsecurity
# ✅ netflixsecurity 共抓到 10 篇文章
# 爬取中: https://netflixtechblog.com/tagged/isp
# ✅ isp 共抓到 3 篇文章
# 爬取中: https://netflixtechblog.com/tagged/streaming-video
# ✅ streaming-video 共抓到 4 篇文章
# 爬取中: https://netflixtechblog.com/tagged/nosql
# ✅ nosql 共抓到 3 篇文章
# 爬取中: https://netflixtechblog.com/tagged/cloud
# ✅ cloud 共抓到 8 篇文章
# 爬取中: https://netflixtechblog.com/tagged/api
# ✅ api 共抓到 9 篇文章
# 爬取中: https://netflixtechblog.com/tagged/netflix-api
# ✅ netflix-api 共抓到 3 篇文章
# 爬取中: https://netflixtechblog.com/tagged/datastax
# ✅ datastax 共抓到 3 篇文章
# 爬取中: https://netflixtechblog.com/tagged/hadoop
# ✅ hadoop 共抓到 10 篇文章
# 爬取中: https://netflixtechblog.com/tagged/cassandra
# ✅ cassandra 共抓到 10 篇文章
# 爬取中: https://netflixtechblog.com/tagged/hbase
# ✅ hbase 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/database
# ✅ database 共抓到 9 篇文章
# 爬取中: https://netflixtechblog.com/tagged/throughput
# ✅ throughput 共抓到 2 篇文章
# 爬取中: https://netflixtechblog.com/tagged/network-performance
# ✅ network-performance 共抓到 3 篇文章
# 爬取中: https://netflixtechblog.com/tagged/product-management
# ✅ product-management 共抓到 2 篇文章
# 爬取中: https://netflixtechblog.com/tagged/fail-fast
# ✅ fail-fast 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/a-b-testing
# ✅ a-b-testing 共抓到 7 篇文章
# 爬取中: https://netflixtechblog.com/tagged/innovation
# ✅ innovation 共抓到 10 篇文章
# 爬取中: https://netflixtechblog.com/tagged/videos
# ✅ videos 共抓到 8 篇文章
# 爬取中: https://netflixtechblog.com/tagged/streaming
# ✅ streaming 共抓到 10 篇文章
# 爬取中: https://netflixtechblog.com/tagged/aws
# ✅ aws 共抓到 9 篇文章
# 爬取中: https://netflixtechblog.com/tagged/cloud-architecture
# ✅ cloud-architecture 共抓到 9 篇文章
# 爬取中: https://netflixtechblog.com/tagged/cloud-computing
# ✅ cloud-computing 共抓到 9 篇文章
# 爬取中: https://netflixtechblog.com/tagged/scaling
# ✅ scaling 共抓到 2 篇文章
# 爬取中: https://netflixtechblog.com/tagged/culture
# ✅ culture 共抓到 4 篇文章
# 爬取中: https://netflixtechblog.com/tagged/movie-production
# ✅ movie-production 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/content-hub
# ✅ content-hub 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/media-workflows
# ✅ media-workflows 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/media-management
# ✅ media-management 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/identity-and-access
# ✅ identity-and-access 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/permission
# ✅ permission 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/ami
# ✅ ami 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/remote-working
# ✅ remote-working 共抓到 2 篇文章
# 爬取中: https://netflixtechblog.com/tagged/saltstack
# ✅ saltstack 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/priority-queue
# ✅ priority-queue 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/marken
# ✅ marken 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/distributed-transaction
# ✅ distributed-transaction 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/cloud-efficiency
# ✅ cloud-efficiency 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/analytics-engineering
# ✅ analytics-engineering 共抓到 3 篇文章
# 爬取中: https://netflixtechblog.com/tagged/data-modeling
# ✅ data-modeling 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/cost
# ✅ cost 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/site-reliability-engineer
# ✅ site-reliability-engineer 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/data-migration
# ✅ data-migration 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/simpledb
# ✅ simpledb 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/high-availability
# ✅ high-availability 共抓到 5 篇文章
# 爬取中: https://netflixtechblog.com/tagged/zuul
# ✅ zuul 共抓到 3 篇文章
# 爬取中: https://netflixtechblog.com/tagged/open-source-software
# ✅ open-source-software 共抓到 2 篇文章
# 爬取中: https://netflixtechblog.com/tagged/denominator
# ✅ denominator 共抓到 3 篇文章
# 爬取中: https://netflixtechblog.com/tagged/concurrency
# ✅ concurrency 共抓到 2 篇文章
# 爬取中: https://netflixtechblog.com/tagged/rxjava
# ✅ rxjava 共抓到 2 篇文章
# 爬取中: https://netflixtechblog.com/tagged/rest
# ✅ rest 共抓到 2 篇文章
# 爬取中: https://netflixtechblog.com/tagged/remote-procedure-calls
# ✅ remote-procedure-calls 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/data-structures
# ✅ data-structures 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/hashmap
# ✅ hashmap 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/programming
# ✅ programming 共抓到 5 篇文章
# 爬取中: https://netflixtechblog.com/tagged/directed-graph
# ✅ directed-graph 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/javascript
# ✅ javascript 共抓到 9 篇文章
# 爬取中: https://netflixtechblog.com/tagged/reactivex
# ✅ reactivex 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/reactive-programming
# ✅ reactive-programming 共抓到 2 篇文章
# 爬取中: https://netflixtechblog.com/tagged/open-source-platform
# ✅ open-source-platform 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/big-data
# ✅ big-data 共抓到 10 篇文章
# 爬取中: https://netflixtechblog.com/tagged/elastic-load-balancer
# ✅ elastic-load-balancer 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/elb
# ✅ elb 共抓到 2 篇文章
# 爬取中: https://netflixtechblog.com/tagged/outage
# ✅ outage 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/quality-assurance
# ✅ quality-assurance 共抓到 2 篇文章
# 爬取中: https://netflixtechblog.com/tagged/supply-chain
# ✅ supply-chain 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/turbine
# ✅ turbine 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/werner-vogels
# ✅ werner-vogels 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/andy-jassy
# ✅ andy-jassy 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/reed-hastings
# ✅ reed-hastings 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/high-volume
# ✅ high-volume 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/deadlock
# ✅ deadlock 共抓到 2 篇文章
# 爬取中: https://netflixtechblog.com/tagged/locks
# ✅ locks 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/locking
# ✅ locking 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/appender
# ✅ appender 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/rca
# ✅ rca 共抓到 2 篇文章
# 爬取中: https://netflixtechblog.com/tagged/research
# ✅ research 共抓到 5 篇文章
# 爬取中: https://netflixtechblog.com/tagged/recommender-systems
# ✅ recommender-systems 共抓到 2 篇文章
# 爬取中: https://netflixtechblog.com/tagged/load-balancing
# ✅ load-balancing 共抓到 4 篇文章
# 爬取中: https://netflixtechblog.com/tagged/eureka
# ✅ eureka 共抓到 2 篇文章
# 爬取中: https://netflixtechblog.com/tagged/failover
# ✅ failover 共抓到 4 篇文章
# 爬取中: https://netflixtechblog.com/tagged/ssd
# ✅ ssd 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/ipv6
# ✅ ipv6 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/netflixoss
# ✅ netflixoss 共抓到 9 篇文章
# 爬取中: https://netflixtechblog.com/tagged/device-proliferation
# ✅ device-proliferation 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/performance
# ✅ performance 共抓到 10 篇文章
# 爬取中: https://netflixtechblog.com/tagged/asgard
# ✅ asgard 共抓到 2 篇文章
# 爬取中: https://netflixtechblog.com/tagged/hive
# ✅ hive 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/s3
# ✅ s3 共抓到 2 篇文章
# 爬取中: https://netflixtechblog.com/tagged/sketchy
# ✅ sketchy 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/scumblr
# ✅ scumblr 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/web-development
# ✅ web-development 共抓到 3 篇文章
# 爬取中: https://netflixtechblog.com/tagged/hackday
# ✅ hackday 共抓到 6 篇文章
# 爬取中: https://netflixtechblog.com/tagged/user-interface
# ✅ user-interface 共抓到 4 篇文章
# 爬取中: https://netflixtechblog.com/tagged/nodejs
# ✅ nodejs 共抓到 6 篇文章
# 爬取中: https://netflixtechblog.com/tagged/scalability
# ✅ scalability 共抓到 8 篇文章
# 爬取中: https://netflixtechblog.com/tagged/security
# ✅ security 共抓到 10 篇文章
# 爬取中: https://netflixtechblog.com/tagged/4k-video
# ✅ 4k-video 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/4k
# ✅ 4k 共抓到 2 篇文章
# 爬取中: https://netflixtechblog.com/tagged/ultra-hd
# ✅ ultra-hd 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/sony
# ✅ sony 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/predictive-modeling
# ✅ predictive-modeling 共抓到 4 篇文章
# 爬取中: https://netflixtechblog.com/tagged/algorithms
# ✅ algorithms 共抓到 7 篇文章
# 爬取中: https://netflixtechblog.com/tagged/safari
# ✅ safari 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/os-x
# ✅ os-x 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/server-side-rendering
# ✅ server-side-rendering 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/payload
# ✅ payload 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/velocity
# ✅ velocity 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/linux
# ✅ linux 共抓到 10 篇文章
# 爬取中: https://netflixtechblog.com/tagged/apache
# ✅ apache 共抓到 2 篇文章
# 爬取中: https://netflixtechblog.com/tagged/threading
# ✅ threading 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/tomcat
# ✅ tomcat 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/latency
# ✅ latency 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/graph
# ✅ graph 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/outliers
# ✅ outliers 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/dbscan
# ✅ dbscan 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/cluster-analysis
# ✅ cluster-analysis 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/f-score
# ✅ f-score 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/appsanddevices
# ✅ appsanddevices 共抓到 2 篇文章
# 爬取中: https://netflixtechblog.com/tagged/netflixdevices
# ✅ netflixdevices 共抓到 3 篇文章
# 爬取中: https://netflixtechblog.com/tagged/architecture
# ✅ architecture 共抓到 7 篇文章
# 爬取中: https://netflixtechblog.com/tagged/internationalization
# ✅ internationalization 共抓到 2 篇文章
# 爬取中: https://netflixtechblog.com/tagged/localization
# ✅ localization 共抓到 3 篇文章
# 爬取中: https://netflixtechblog.com/tagged/co2
# ✅ co2 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/carbon-footprint
# ✅ carbon-footprint 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/energy
# ✅ energy 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/energy-efficiency
# ✅ energy-efficiency 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/search
# ✅ search 共抓到 10 篇文章
# 爬取中: https://netflixtechblog.com/tagged/complex-event-processing
# ✅ complex-event-processing 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/kafka
# ✅ kafka 共抓到 5 篇文章
# 爬取中: https://netflixtechblog.com/tagged/chukwa
# ✅ chukwa 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/spark
# ✅ spark 共抓到 2 篇文章
# 爬取中: https://netflixtechblog.com/tagged/thrift-api
# ✅ thrift-api 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/cql
# ✅ cql 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/dynomite
# ✅ dynomite 共抓到 6 篇文章
# 爬取中: https://netflixtechblog.com/tagged/redis
# ✅ redis 共抓到 7 篇文章
# 爬取中: https://netflixtechblog.com/tagged/integration-testing
# ✅ integration-testing 共抓到 2 篇文章
# 爬取中: https://netflixtechblog.com/tagged/photon
# ✅ photon 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/cloud-gateway
# ✅ cloud-gateway 共抓到 2 篇文章
# 爬取中: https://netflixtechblog.com/tagged/msl
# ✅ msl 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/workflow
# ✅ workflow 共抓到 10 篇文章
# 爬取中: https://netflixtechblog.com/tagged/download
# ✅ download 共抓到 2 篇文章
# 爬取中: https://netflixtechblog.com/tagged/chatops
# ❌ https://netflixtechblog.com/tagged/chatops 請求失敗: HTTPSConnectionPool(host='netflixtechblog.com', port=443): Read timed out. (read timeout=10)
# ✅ chatops 共抓到 0 篇文章
# 爬取中: https://netflixtechblog.com/tagged/github
# ✅ github 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/tls
# ✅ tls 共抓到 3 篇文章
# 爬取中: https://netflixtechblog.com/tagged/orchestration
# ✅ orchestration 共抓到 5 篇文章
# 爬取中: https://netflixtechblog.com/tagged/inversion-of-control
# ✅ inversion-of-control 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/ruby-on-rails
# ✅ ruby-on-rails 共抓到 2 篇文章
# 爬取中: https://netflixtechblog.com/tagged/ember
# ✅ ember 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/ruby
# ✅ ruby 共抓到 2 篇文章
# 爬取中: https://netflixtechblog.com/tagged/dependencies
# ✅ dependencies 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/containers
# ✅ containers 共抓到 9 篇文章
# 爬取中: https://netflixtechblog.com/tagged/application-development
# ✅ application-development 共抓到 2 篇文章
# 爬取中: https://netflixtechblog.com/tagged/serverless
# ✅ serverless 共抓到 3 篇文章
# 爬取中: https://netflixtechblog.com/tagged/developer-experience
# ✅ developer-experience 共抓到 2 篇文章
# 爬取中: https://netflixtechblog.com/tagged/hdr
# ✅ hdr 共抓到 6 篇文章
# 爬取中: https://netflixtechblog.com/tagged/declarative
# ✅ declarative 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/storage
# ✅ storage 共抓到 2 篇文章
# 爬取中: https://netflixtechblog.com/tagged/servers
# ✅ servers 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/ttml2
# ✅ ttml2 共抓到 2 篇文章
# 爬取中: https://netflixtechblog.com/tagged/japanese-subtitles
# ✅ japanese-subtitles 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/subtitles
# ✅ subtitles 共抓到 2 篇文章
# 爬取中: https://netflixtechblog.com/tagged/adtech
# ✅ adtech 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/marketing-operations
# ✅ marketing-operations 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/marketing
# ✅ marketing 共抓到 2 篇文章
# 爬取中: https://netflixtechblog.com/tagged/engineering
# ✅ engineering 共抓到 6 篇文章
# 爬取中: https://netflixtechblog.com/tagged/digital-marketing
# ✅ digital-marketing 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/space
# ✅ space 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/webgl
# ✅ webgl 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/traffic-optimization
# ✅ traffic-optimization 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/traffic-management
# ✅ traffic-management 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/optimization-algorithms
# ✅ optimization-algorithms 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/media-processing
# ✅ media-processing 共抓到 2 篇文章
# 爬取中: https://netflixtechblog.com/tagged/hive-metastore
# ✅ hive-metastore 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/request-tracing
# ✅ request-tracing 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/monitoring
# ✅ monitoring 共抓到 3 篇文章
# 爬取中: https://netflixtechblog.com/tagged/conformity-monkey
# ✅ conformity-monkey 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/eucalyptus
# ✅ eucalyptus 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/ibm
# ✅ ibm 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/apache-pig
# ✅ apache-pig 共抓到 2 篇文章
# 爬取中: https://netflixtechblog.com/tagged/premium-video-extensions
# ✅ premium-video-extensions 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/genie
# ✅ genie 共抓到 3 篇文章
# 爬取中: https://netflixtechblog.com/tagged/women-in-tech
# ✅ women-in-tech 共抓到 3 篇文章
# 爬取中: https://netflixtechblog.com/tagged/cloud-now
# ✅ cloud-now 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/metadata
# ✅ metadata 共抓到 2 篇文章
# 爬取中: https://netflixtechblog.com/tagged/microservices
# ✅ microservices 共抓到 9 篇文章
# 爬取中: https://netflixtechblog.com/tagged/silverlight
# ✅ silverlight 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/media-source-extensions
# ✅ media-source-extensions 共抓到 3 篇文章
# 爬取中: https://netflixtechblog.com/tagged/webcrypto
# ✅ webcrypto 共抓到 3 篇文章
# 爬取中: https://netflixtechblog.com/tagged/cloud-prize
# ✅ cloud-prize 共抓到 3 篇文章
# 爬取中: https://netflixtechblog.com/tagged/karyon
# ✅ karyon 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/animator
# ✅ animator 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/amazon-machine-images
# ✅ amazon-machine-images 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/jenkins
# ✅ jenkins 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/ci
# ✅ ci 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/archaius
# ✅ archaius 共抓到 2 篇文章
# 爬取中: https://netflixtechblog.com/tagged/python
# ✅ python 共抓到 6 篇文章
# 爬取中: https://netflixtechblog.com/tagged/python-programming
# ✅ python-programming 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/blitz4j
# ✅ blitz4j 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/evcache
# ✅ evcache 共抓到 5 篇文章
# 爬取中: https://netflixtechblog.com/tagged/media-document
# ✅ media-document 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/data-schema
# ✅ data-schema 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/schema-on-write
# ✅ schema-on-write 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/graphql
# ✅ graphql 共抓到 10 篇文章
# 爬取中: https://netflixtechblog.com/tagged/osquery
# ✅ osquery 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/electron
# ✅ electron 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/endpoint-security
# ✅ endpoint-security 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/dashboard
# ✅ dashboard 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/distributed-database
# ✅ distributed-database 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/nmdb
# ✅ nmdb 共抓到 3 篇文章
# 爬取中: https://netflixtechblog.com/tagged/media-timeline
# ✅ media-timeline 共抓到 3 篇文章
# 爬取中: https://netflixtechblog.com/tagged/software-engineering
# ✅ software-engineering 共抓到 9 篇文章
# 爬取中: https://netflixtechblog.com/tagged/production-technology
# ✅ production-technology 共抓到 2 篇文章
# 爬取中: https://netflixtechblog.com/tagged/producing
# ✅ producing 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/prodicle
# ✅ prodicle 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/film-production
# ✅ film-production 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/microservice-architecture
# ✅ microservice-architecture 共抓到 6 篇文章
# 爬取中: https://netflixtechblog.com/tagged/scientific-software
# ✅ scientific-software 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/scientific-research
# ✅ scientific-research 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/chrome
# ✅ chrome 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/amazon-s3
# ✅ amazon-s3 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/reliability-engineering
# ✅ reliability-engineering 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/data
# ✅ data 共抓到 9 篇文章
# 爬取中: https://netflixtechblog.com/tagged/bpf
# ✅ bpf 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/product-design
# ✅ product-design 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/messaging
# ✅ messaging 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/product-development
# ✅ product-development 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/in-app-messaging
# ✅ in-app-messaging 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/workflow-automation
# ✅ workflow-automation 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/graphics
# ✅ graphics 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/user-interface-design
# ✅ user-interface-design 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/javascript-development
# ✅ javascript-development 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/productivity
# ✅ productivity 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/data-compression
# ✅ data-compression 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/nostalgia
# ✅ nostalgia 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/customer-service
# ✅ customer-service 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/image-classification
# ✅ image-classification 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/risk
# ✅ risk 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/information-security
# ✅ information-security 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/studio
# ✅ studio 共抓到 2 篇文章
# 爬取中: https://netflixtechblog.com/tagged/production
# ✅ production 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/entertainment
# ✅ entertainment 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/experimentation-culture
# ✅ experimentation-culture 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/hdmi
# ✅ hdmi 共抓到 2 篇文章
# 爬取中: https://netflixtechblog.com/tagged/set-top-box
# ✅ set-top-box 共抓到 3 篇文章
# 爬取中: https://netflixtechblog.com/tagged/distributed-tracing
# ✅ distributed-tracing 共抓到 2 篇文章
# 爬取中: https://netflixtechblog.com/tagged/akka-streams
# ✅ akka-streams 共抓到 0 篇文章
# 爬取中: https://netflixtechblog.com/tagged/akka-actor
# ✅ akka-actor 共抓到 0 篇文章
# 爬取中: https://netflixtechblog.com/tagged/load-shedding
# ✅ load-shedding 共抓到 2 篇文章
# 爬取中: https://netflixtechblog.com/tagged/kotlin
# ✅ kotlin 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/kotlin-multiplatform
# ✅ kotlin-multiplatform 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/data-warehouse
# ✅ data-warehouse 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/batch-processing
# ✅ batch-processing 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/key-value-store
# ✅ key-value-store 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/etl
# ✅ etl 共抓到 2 篇文章
# 爬取中: https://netflixtechblog.com/tagged/data-movement
# ✅ data-movement 共抓到 2 篇文章
# 爬取中: https://netflixtechblog.com/tagged/design-systems
# ✅ design-systems 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/component-libraries
# ✅ component-libraries 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/build-vs-buy
# ✅ build-vs-buy 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/authorization
# ✅ authorization 共抓到 2 篇文章
# 爬取中: https://netflixtechblog.com/tagged/identity-management
# ✅ identity-management 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/spring-boot
# ✅ spring-boot 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/growth
# ✅ growth 共抓到 2 篇文章
# 爬取中: https://netflixtechblog.com/tagged/network-analytics
# ✅ network-analytics 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/ebpf
# ✅ ebpf 共抓到 4 篇文章
# 爬取中: https://netflixtechblog.com/tagged/decision-making
# ✅ decision-making 共抓到 7 篇文章
# 爬取中: https://netflixtechblog.com/tagged/protocol-buffers
# ✅ protocol-buffers 共抓到 2 篇文章
# 爬取中: https://netflixtechblog.com/tagged/api-design
# ✅ api-design 共抓到 2 篇文章
# 爬取中: https://netflixtechblog.com/tagged/grpc
# ✅ grpc 共抓到 2 篇文章
# 爬取中: https://netflixtechblog.com/tagged/reactive-streams
# ✅ reactive-streams 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/alpakka
# ✅ alpakka 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/regression
# ✅ regression 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/changepoint
# ✅ changepoint 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/anomaly
# ✅ anomaly 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/auto-remediation
# ✅ auto-remediation 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/message-queue
# ✅ message-queue 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/appsec
# ✅ appsec 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/hiring
# ✅ hiring 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/ci-cd-pipeline
# ✅ ci-cd-pipeline 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/deployment
# ✅ deployment 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/data-management
# ✅ data-management 共抓到 2 篇文章
# 爬取中: https://netflixtechblog.com/tagged/certificate
# ✅ certificate 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/bettertls
# ✅ bettertls 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/mobile-apps
# ✅ mobile-apps 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/video-editing
# ✅ video-editing 共抓到 3 篇文章
# 爬取中: https://netflixtechblog.com/tagged/cloud-rendering
# ✅ cloud-rendering 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/vfx
# ✅ vfx 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/improve-video-quality
# ✅ improve-video-quality 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/jdk-8180450
# ✅ jdk-8180450 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/vtune
# ✅ vtune 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/pmc
# ✅ pmc 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/mlops
# ✅ mlops 共抓到 2 篇文章
# 爬取中: https://netflixtechblog.com/tagged/apache-iceberg
# ✅ apache-iceberg 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/data-accuracy
# ✅ data-accuracy 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/automated-catchup
# ✅ automated-catchup 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/data-integrity
# ✅ data-integrity 共抓到 3 篇文章
# 爬取中: https://netflixtechblog.com/tagged/icebergs
# ✅ icebergs 共抓到 3 篇文章
# 爬取中: https://netflixtechblog.com/tagged/speech
# ✅ speech 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/music-classification
# ✅ music-classification 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/troubleshooting
# ✅ troubleshooting 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/cpu
# ✅ cpu 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/jupyter-notebook
# ✅ jupyter-notebook 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/live-streaming
# ✅ live-streaming 共抓到 2 篇文章
# 爬取中: https://netflixtechblog.com/tagged/clojure
# ✅ clojure 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/pigs
# ✅ pigs 共抓到 2 篇文章
# 爬取中: https://netflixtechblog.com/tagged/mapreduce
# ✅ mapreduce 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/encoding
# ✅ encoding 共抓到 9 篇文章
# 爬取中: https://netflixtechblog.com/tagged/accelerated-compositing
# ✅ accelerated-compositing 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/logging
# ✅ logging 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/data-pipeline
# ✅ data-pipeline 共抓到 10 篇文章
# 爬取中: https://netflixtechblog.com/tagged/suro
# ✅ suro 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/zeno
# ✅ zeno 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/tv
# ✅ tv 共抓到 3 篇文章
# 爬取中: https://netflixtechblog.com/tagged/devices
# ✅ devices 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/tvs
# ✅ tvs 共抓到 3 篇文章
# 爬取中: https://netflixtechblog.com/tagged/winner
# ✅ winner 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/predictions
# ✅ predictions 共抓到 2 篇文章
# 爬取中: https://netflixtechblog.com/tagged/analytics
# ✅ analytics 共抓到 10 篇文章
# 爬取中: https://netflixtechblog.com/tagged/availability
# ✅ availability 共抓到 2 篇文章
# 爬取中: https://netflixtechblog.com/tagged/continuous-integration
# ✅ continuous-integration 共抓到 4 篇文章
# 爬取中: https://netflixtechblog.com/tagged/insights
# ✅ insights 共抓到 3 篇文章
# 爬取中: https://netflixtechblog.com/tagged/automation
# ✅ automation 共抓到 10 篇文章
# 爬取中: https://netflixtechblog.com/tagged/continuous-delivery
# ✅ continuous-delivery 共抓到 10 篇文章
# 爬取中: https://netflixtechblog.com/tagged/anomaly-detection
# ✅ anomaly-detection 共抓到 3 篇文章
# 爬取中: https://netflixtechblog.com/tagged/rpca
# ✅ rpca 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/optimization
# ✅ optimization 共抓到 5 篇文章
# 爬取中: https://netflixtechblog.com/tagged/observability
# ✅ observability 共抓到 10 篇文章
# 爬取中: https://netflixtechblog.com/tagged/isolation
# ✅ isolation 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/stream-processing
# ✅ stream-processing 共抓到 10 篇文章
# 爬取中: https://netflixtechblog.com/tagged/modules
# ✅ modules 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/class-loader
# ✅ class-loader 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/site-reliability
# ✅ site-reliability 共抓到 3 篇文章
# 爬取中: https://netflixtechblog.com/tagged/operational-excellence
# ✅ operational-excellence 共抓到 2 篇文章
# 爬取中: https://netflixtechblog.com/tagged/devops
# ✅ devops 共抓到 8 篇文章
# 爬取中: https://netflixtechblog.com/tagged/react
# ✅ react 共抓到 9 篇文章
# 爬取中: https://netflixtechblog.com/tagged/memcached
# ✅ memcached 共抓到 2 篇文章
# 爬取中: https://netflixtechblog.com/tagged/telemetry
# ✅ telemetry 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/dockerhub
# ✅ dockerhub 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/docker
# ✅ docker 共抓到 8 篇文章
# 爬取中: https://netflixtechblog.com/tagged/emr
# ✅ emr 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/cloud-database
# ✅ cloud-database 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/elasticsearch
# ✅ elasticsearch 共抓到 9 篇文章
# 爬取中: https://netflixtechblog.com/tagged/raigad
# ✅ raigad 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/prana
# ✅ prana 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/sidecar
# ✅ sidecar 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/data-replication
# ✅ data-replication 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/sharding
# ✅ sharding 共抓到 2 篇文章
# 爬取中: https://netflixtechblog.com/tagged/cryptography
# ✅ cryptography 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/https
# ✅ https 共抓到 3 篇文章
# 爬取中: https://netflixtechblog.com/tagged/authentication
# ✅ authentication 共抓到 2 篇文章
# 爬取中: https://netflixtechblog.com/tagged/failure-injection
# ✅ failure-injection 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/testing
# ✅ testing 共抓到 8 篇文章
# 爬取中: https://netflixtechblog.com/tagged/test-automation
# ✅ test-automation 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/android
# ✅ android 共抓到 7 篇文章
# 爬取中: https://netflixtechblog.com/tagged/awsreinvent
# ✅ awsreinvent 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/spinnaker
# ✅ spinnaker 共抓到 7 篇文章
# 爬取中: https://netflixtechblog.com/tagged/chaos-engineering
# ✅ chaos-engineering 共抓到 6 篇文章
# 爬取中: https://netflixtechblog.com/tagged/chaos-kong
# ✅ chaos-kong 共抓到 2 篇文章
# 爬取中: https://netflixtechblog.com/tagged/virtual-reality
# ✅ virtual-reality 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/oculus-connect
# ✅ oculus-connect 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/samsung-gear-vr
# ✅ samsung-gear-vr 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/oculus
# ✅ oculus 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/gearvr
# ✅ gearvr 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/computer-vision
# ✅ computer-vision 共抓到 9 篇文章
# 爬取中: https://netflixtechblog.com/tagged/pki
# ✅ pki 共抓到 2 篇文章
# 爬取中: https://netflixtechblog.com/tagged/ssl
# ✅ ssl 共抓到 3 篇文章
# 爬取中: https://netflixtechblog.com/tagged/sleepy-puppy
# ✅ sleepy-puppy 共抓到 2 篇文章
# 爬取中: https://netflixtechblog.com/tagged/xs
# ✅ xs 共抓到 2 篇文章
# 爬取中: https://netflixtechblog.com/tagged/cross-site-scripting
# ✅ cross-site-scripting 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/bin-packing
# ✅ bin-packing 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/fenzo
# ✅ fenzo 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/cluster-autoscaling
# ✅ cluster-autoscaling 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/scheduling
# ✅ scheduling 共抓到 2 篇文章
# 爬取中: https://netflixtechblog.com/tagged/mesos
# ✅ mesos 共抓到 3 篇文章
# 爬取中: https://netflixtechblog.com/tagged/falcor
# ✅ falcor 共抓到 2 篇文章
# 爬取中: https://netflixtechblog.com/tagged/imsc
# ✅ imsc 共抓到 3 篇文章
# 爬取中: https://netflixtechblog.com/tagged/ttml
# ✅ ttml 共抓到 4 篇文章
# 爬取中: https://netflixtechblog.com/tagged/john-stamos
# ✅ john-stamos 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/april-fools
# ✅ april-fools 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/xr
# ✅ xr 共抓到 2 篇文章
# 爬取中: https://netflixtechblog.com/tagged/rxjs
# ✅ rxjs 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/content-metadata
# ✅ content-metadata 共抓到 2 篇文章
# 爬取中: https://netflixtechblog.com/tagged/real-time-streaming
# ✅ real-time-streaming 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/aminator
# ✅ aminator 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/bake
# ✅ bake 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/imf
# ✅ imf 共抓到 4 篇文章
# 爬取中: https://netflixtechblog.com/tagged/workshop
# ✅ workshop 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/workshopprs
# ✅ workshopprs 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/artwork
# ✅ artwork 共抓到 4 篇文章
# 爬取中: https://netflixtechblog.com/tagged/experimentation
# ✅ experimentation 共抓到 10 篇文章
# 爬取中: https://netflixtechblog.com/tagged/ab-testing
# ✅ ab-testing 共抓到 9 篇文章
# 爬取中: https://netflixtechblog.com/tagged/distributed-systems
# ✅ distributed-systems 共抓到 10 篇文章
# 爬取中: https://netflixtechblog.com/tagged/keystone
# ✅ keystone 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/timed-text
# ✅ timed-text 共抓到 3 篇文章
# 爬取中: https://netflixtechblog.com/tagged/efficiency
# ✅ efficiency 共抓到 2 篇文章
# 爬取中: https://netflixtechblog.com/tagged/flamegraphs
# ❌ https://netflixtechblog.com/tagged/flamegraphs 請求失敗: HTTPSConnectionPool(host='medium.com', port=443): Read timed out. (read timeout=10)
# ✅ flamegraphs 共抓到 0 篇文章
# 爬取中: https://netflixtechblog.com/tagged/flux
# ✅ flux 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/traffic
# ✅ traffic 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/vizceral
# ✅ vizceral 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/titus
# ✅ titus 共抓到 6 篇文章
# 爬取中: https://netflixtechblog.com/tagged/mantis
# ✅ mantis 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/apache-mesos
# ✅ apache-mesos 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/migration
# ✅ migration 共抓到 2 篇文章
# 爬取中: https://netflixtechblog.com/tagged/original
# ✅ original 共抓到 2 篇文章
# 爬取中: https://netflixtechblog.com/tagged/media-pipeline
# ✅ media-pipeline 共抓到 2 篇文章
# 爬取中: https://netflixtechblog.com/tagged/continue-watching
# ✅ continue-watching 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/reinvent
# ✅ reinvent 共抓到 3 篇文章
# 爬取中: https://netflixtechblog.com/tagged/fps
# ✅ fps 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/gcp
# ✅ gcp 共抓到 0 篇文章
# 爬取中: https://netflixtechblog.com/tagged/google-cloud-platform
# ✅ google-cloud-platform 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/ux
# ✅ ux 共抓到 2 篇文章
# 爬取中: https://netflixtechblog.com/tagged/networking
# ✅ networking 共抓到 2 篇文章
# 爬取中: https://netflixtechblog.com/tagged/statistics
# ✅ statistics 共抓到 5 篇文章
# 爬取中: https://netflixtechblog.com/tagged/testing-tools
# ✅ testing-tools 共抓到 2 篇文章
# 爬取中: https://netflixtechblog.com/tagged/simulation
# ✅ simulation 共抓到 2 篇文章
# 爬取中: https://netflixtechblog.com/tagged/scale
# ✅ scale 共抓到 2 篇文章
# 爬取中: https://netflixtechblog.com/tagged/cloud-security
# ✅ cloud-security 共抓到 5 篇文章
# 爬取中: https://netflixtechblog.com/tagged/raspberry-pi
# ✅ raspberry-pi 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/software-architecture
# ✅ software-architecture 共抓到 7 篇文章
# 爬取中: https://netflixtechblog.com/tagged/event-sourcing
# ✅ event-sourcing 共抓到 3 篇文章
# 爬取中: https://netflixtechblog.com/tagged/download-videos
# ✅ download-videos 共抓到 2 篇文章
# 爬取中: https://netflixtechblog.com/tagged/container-orchestration
# ✅ container-orchestration 共抓到 4 篇文章
# 爬取中: https://netflixtechblog.com/tagged/image-processing
# ✅ image-processing 共抓到 3 篇文章
# 爬取中: https://netflixtechblog.com/tagged/image-recognition
# ✅ image-recognition 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/json-api
# ✅ json-api 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/rubygems
# ✅ rubygems 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/api-gateway
# ✅ api-gateway 共抓到 3 篇文章
# 爬取中: https://netflixtechblog.com/tagged/cloud-services
# ✅ cloud-services 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/sdlc
# ✅ sdlc 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/日本語字幕
# ✅ 日本語字幕 共抓到 0 篇文章
# 爬取中: https://netflixtechblog.com/tagged/縦字幕
# ✅ 縦字幕 共抓到 0 篇文章
# 爬取中: https://netflixtechblog.com/tagged/組み文字
# ✅ 組み文字 共抓到 0 篇文章
# 爬取中: https://netflixtechblog.com/tagged/ルビ
# ✅ ルビ 共抓到 0 篇文章
# 爬取中: https://netflixtechblog.com/tagged/cinema
# ✅ cinema 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/image
# ✅ image 共抓到 2 篇文章
# 爬取中: https://netflixtechblog.com/tagged/quasi-experiment
# ✅ quasi-experiment 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/causal-inference
# ✅ causal-inference 共抓到 10 篇文章
# 爬取中: https://netflixtechblog.com/tagged/bootstrap
# ✅ bootstrap 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/video-production
# ✅ video-production 共抓到 2 篇文章
# 爬取中: https://netflixtechblog.com/tagged/content-creation
# ✅ content-creation 共抓到 2 篇文章
# 爬取中: https://netflixtechblog.com/tagged/post-production
# ✅ post-production 共抓到 2 篇文章
# 爬取中: https://netflixtechblog.com/tagged/keystone-data-pipeline
# ✅ keystone-data-pipeline 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/advertising
# ✅ advertising 共抓到 2 篇文章
# 爬取中: https://netflixtechblog.com/tagged/jupyter
# ✅ jupyter 共抓到 2 篇文章
# 爬取中: https://netflixtechblog.com/tagged/nteract
# ✅ nteract 共抓到 2 篇文章
# 爬取中: https://netflixtechblog.com/tagged/color-science
# ✅ color-science 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/film-and-television
# ✅ film-and-television 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/film-history
# ✅ film-history 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/color-management
# ✅ color-management 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/budget-optimization
# ✅ budget-optimization 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/campaign-management
# ✅ campaign-management 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/meta-analysis
# ✅ meta-analysis 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/experiment
# ✅ experiment 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/statistical-inference
# ✅ statistical-inference 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/rxjava2
# ✅ rxjava2 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/encoder
# ✅ encoder 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/av1
# ✅ av1 共抓到 6 篇文章
# 爬取中: https://netflixtechblog.com/tagged/video-codec
# ✅ video-codec 共抓到 2 篇文章
# 爬取中: https://netflixtechblog.com/tagged/aom
# ✅ aom 共抓到 2 篇文章
# 爬取中: https://netflixtechblog.com/tagged/svt
# ✅ svt 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/windows
# ✅ windows 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/video-compression
# ✅ video-compression 共抓到 3 篇文章
# 爬取中: https://netflixtechblog.com/tagged/api-integration
# ✅ api-integration 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/hexagonal-architecture
# ✅ hexagonal-architecture 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/kubernetes
# ✅ kubernetes 共抓到 2 篇文章
# 爬取中: https://netflixtechblog.com/tagged/data-platforms
# ✅ data-platforms 共抓到 2 篇文章
# 爬取中: https://netflixtechblog.com/tagged/big-data-infrastructure
# ✅ big-data-infrastructure 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/distributed-computing
# ✅ distributed-computing 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/serverless-computing
# ✅ serverless-computing 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/award-winning
# ✅ award-winning 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/file-format
# ✅ file-format 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/graphql-vs-rest
# ✅ graphql-vs-rest 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/rapid-prototyping
# ✅ rapid-prototyping 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/netflix-engineering
# ✅ netflix-engineering 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/rule-based-platform
# ✅ rule-based-platform 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/membership-engineering
# ✅ membership-engineering 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/data-tools
# ✅ data-tools 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/vuejs
# ✅ vuejs 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/specifications
# ✅ specifications 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/dubbing
# ✅ dubbing 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/data-mesh
# ✅ data-mesh 共抓到 3 篇文章
# 爬取中: https://netflixtechblog.com/tagged/data-streaming
# ✅ data-streaming 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/webpack
# ✅ webpack 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/micro-frontends
# ✅ micro-frontends 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/typescript
# ✅ typescript 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/recruiting
# ✅ recruiting 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/gaming
# ✅ gaming 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/back-end-development
# ✅ back-end-development 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/indexing
# ✅ indexing 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/recommendation-system
# ✅ recommendation-system 共抓到 2 篇文章
# 爬取中: https://netflixtechblog.com/tagged/icvfx
# ✅ icvfx 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/validation
# ✅ validation 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/unreal-engine
# ✅ unreal-engine 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/game-engine
# ✅ game-engine 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/virtual-production
# ✅ virtual-production 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/distributed-cache
# ✅ distributed-cache 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/data-processing
# ✅ data-processing 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/causality
# ✅ causality 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/creative-production
# ✅ creative-production 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/fuse
# ✅ fuse 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/system-migration
# ✅ system-migration 共抓到 2 篇文章
# 爬取中: https://netflixtechblog.com/tagged/multimodal
# ✅ multimodal 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/nlp
# ✅ nlp 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/information-technology
# ✅ information-technology 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/apple
# ✅ apple 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/mac
# ✅ mac 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/mdm
# ✅ mdm 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/qms
# ✅ qms 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/envoy
# ✅ envoy 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/ipc
# ✅ ipc 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/service-mesh
# ✅ service-mesh 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/kernel-panic
# ✅ kernel-panic 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/data-engineer
# ✅ data-engineer 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/reward-engineering
# ✅ reward-engineering 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/data-architecture
# ✅ data-architecture 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/cqrs
# ✅ cqrs 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/tudum
# ✅ tudum 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/software-development
# ✅ software-development 共抓到 9 篇文章
# 爬取中: https://netflixtechblog.com/tagged/open-source
# ✅ open-source 共抓到 9 篇文章
# 爬取中: https://netflixtechblog.com/tagged/mobile-app-development
# ✅ mobile-app-development 共抓到 2 篇文章
# 爬取中: https://netflixtechblog.com/tagged/html5
# ✅ html5 共抓到 8 篇文章
# 爬取中: https://netflixtechblog.com/tagged/ui-design
# ✅ ui-design 共抓到 0 篇文章
# 爬取中: https://netflixtechblog.com/tagged/ps3
# ✅ ps3 共抓到 0 篇文章
# 爬取中: https://netflixtechblog.com/tagged/technology
# ✅ technology 共抓到 10 篇文章
# 爬取中: https://netflixtechblog.com/tagged/netflix
# ✅ netflix 共抓到 10 篇文章
# 爬取中: https://netflixtechblog.com/tagged/data-science
# ✅ data-science 共抓到 9 篇文章
# 爬取中: https://netflixtechblog.com/tagged/consumer-data-science
# ✅ consumer-data-science 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/configuration-management
# ✅ configuration-management 共抓到 2 篇文章
# 爬取中: https://netflixtechblog.com/tagged/configuration
# ✅ configuration 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/recommendations
# ✅ recommendations 共抓到 10 篇文章
# 爬取中: https://netflixtechblog.com/tagged/personalization
# ✅ personalization 共抓到 9 篇文章
# 爬取中: https://netflixtechblog.com/tagged/machine-learning
# ✅ machine-learning 共抓到 10 篇文章
# 爬取中: https://netflixtechblog.com/tagged/android-app-development
# ✅ android-app-development 共抓到 2 篇文章
# 爬取中: https://netflixtechblog.com/tagged/astyanax
# ✅ astyanax 共抓到 5 篇文章
# 爬取中: https://netflixtechblog.com/tagged/load-testing
# ✅ load-testing 共抓到 2 篇文章
# 爬取中: https://netflixtechblog.com/tagged/jmeter
# ✅ jmeter 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/thrift
# ✅ thrift 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/fault-tolerance
# ✅ fault-tolerance 共抓到 8 篇文章
# 爬取中: https://netflixtechblog.com/tagged/hystrix
# ✅ hystrix 共抓到 3 篇文章
# 爬取中: https://netflixtechblog.com/tagged/resilience
# ✅ resilience 共抓到 8 篇文章
# 爬取中: https://netflixtechblog.com/tagged/reliability
# ✅ reliability 共抓到 9 篇文章
# 爬取中: https://netflixtechblog.com/tagged/aegisthus
# ✅ aegisthus 共抓到 2 篇文章
# 爬取中: https://netflixtechblog.com/tagged/big-data-and-analytics
# ✅ big-data-and-analytics 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/priam
# ✅ priam 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/metrics
# ✅ metrics 共抓到 5 篇文章
# 爬取中: https://netflixtechblog.com/tagged/servo
# ✅ servo 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/caching
# ✅ caching 共抓到 8 篇文章
# 爬取中: https://netflixtechblog.com/tagged/autoscaling
# ✅ autoscaling 共抓到 5 篇文章
# 爬取中: https://netflixtechblog.com/tagged/distributed
# ✅ distributed 共抓到 8 篇文章
# 爬取中: https://netflixtechblog.com/tagged/coordination
# ✅ coordination 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/benchmark
# ✅ benchmark 共抓到 3 篇文章
# 爬取中: https://netflixtechblog.com/tagged/ui
# ✅ ui 共抓到 9 篇文章
# 爬取中: https://netflixtechblog.com/tagged/inheritance
# ✅ inheritance 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/codechix
# ✅ codechix 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/cloudnow
# ✅ cloudnow 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/user-experience
# ✅ user-experience 共抓到 2 篇文章
# 爬取中: https://netflixtechblog.com/tagged/java
# ✅ java 共抓到 7 篇文章
# 爬取中: https://netflixtechblog.com/tagged/responsive-web-design
# ✅ responsive-web-design 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/prototyping
# ✅ prototyping 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/smart-devices
# ✅ smart-devices 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/hackathons
# ✅ hackathons 共抓到 9 篇文章
# 爬取中: https://netflixtechblog.com/tagged/tech
# ✅ tech 共抓到 4 篇文章
# 爬取中: https://netflixtechblog.com/tagged/gpu
# ✅ gpu 共抓到 2 篇文章
# 爬取中: https://netflixtechblog.com/tagged/cuda
# ✅ cuda 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/deep-learning
# ✅ deep-learning 共抓到 5 篇文章
# 爬取中: https://netflixtechblog.com/tagged/operational-visibility
# ✅ operational-visibility 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/operational-insight
# ✅ operational-insight 共抓到 5 篇文章
# 爬取中: https://netflixtechblog.com/tagged/data-visualization
# ✅ data-visualization 共抓到 7 篇文章
# 爬取中: https://netflixtechblog.com/tagged/real-time-insights
# ✅ real-time-insights 共抓到 2 篇文章
# 爬取中: https://netflixtechblog.com/tagged/fido
# ✅ fido 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/alerts
# ✅ alerts 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/cybersecurity
# ✅ cybersecurity 共抓到 2 篇文章
# 爬取中: https://netflixtechblog.com/tagged/page-generation
# ✅ page-generation 共抓到 2 篇文章
# 爬取中: https://netflixtechblog.com/tagged/performance-co-pilot
# ✅ performance-co-pilot 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/vector
# ✅ vector 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/text-recognition
# ✅ text-recognition 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/payments
# ✅ payments 共抓到 2 篇文章
# 爬取中: https://netflixtechblog.com/tagged/billing
# ✅ billing 共抓到 4 篇文章
# 爬取中: https://netflixtechblog.com/tagged/meetup
# ✅ meetup 共抓到 2 篇文章
# 爬取中: https://netflixtechblog.com/tagged/apache-spark
# ✅ apache-spark 共抓到 2 篇文章
# 爬取中: https://netflixtechblog.com/tagged/apache-kafka
# ✅ apache-kafka 共抓到 2 篇文章
# 爬取中: https://netflixtechblog.com/tagged/nintendo
# ✅ nintendo 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/playback
# ✅ playback 共抓到 3 篇文章
# 爬取中: https://netflixtechblog.com/tagged/quality-content
# ✅ quality-content 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/quality-control
# ✅ quality-control 共抓到 2 篇文章
# 爬取中: https://netflixtechblog.com/tagged/video-encoding
# ✅ video-encoding 共抓到 10 篇文章
# 爬取中: https://netflixtechblog.com/tagged/video-quality
# ✅ video-quality 共抓到 10 篇文章
# 爬取中: https://netflixtechblog.com/tagged/content-delivery
# ✅ content-delivery 共抓到 2 篇文章
# 爬取中: https://netflixtechblog.com/tagged/os
# ✅ os 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/quality-metrics
# ✅ quality-metrics 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/meson
# ✅ meson 共抓到 2 篇文章
# 爬取中: https://netflixtechblog.com/tagged/infrastructure
# ✅ infrastructure 共抓到 5 篇文章
# 爬取中: https://netflixtechblog.com/tagged/ios
# ✅ ios 共抓到 3 篇文章
# 爬取中: https://netflixtechblog.com/tagged/animation
# ✅ animation 共抓到 2 篇文章
# 爬取中: https://netflixtechblog.com/tagged/mobile
# ✅ mobile 共抓到 3 篇文章
# 爬取中: https://netflixtechblog.com/tagged/queue
# ✅ queue 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/open-connect
# ✅ open-connect 共抓到 3 篇文章
# 爬取中: https://netflixtechblog.com/tagged/fill
# ✅ fill 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/software-testing
# ✅ software-testing 共抓到 2 篇文章
# 爬取中: https://netflixtechblog.com/tagged/internet-speed
# ✅ internet-speed 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/network-speed
# ✅ network-speed 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/aes-ni
# ✅ aes-ni 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/freebsd
# ✅ freebsd 共抓到 2 篇文章
# 爬取中: https://netflixtechblog.com/tagged/encryption
# ✅ encryption 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/aes-gcm
# ✅ aes-gcm 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/dare
# ✅ dare 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/winston
# ✅ winston 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/chao
# ✅ chao 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/4k-ultra-hd
# ✅ 4k-ultra-hd 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/windows-10
# ✅ windows-10 共抓到 2 篇文章
# 爬取中: https://netflixtechblog.com/tagged/microsoft-edge
# ✅ microsoft-edge 共抓到 2 篇文章
# 爬取中: https://netflixtechblog.com/tagged/internet
# ✅ internet 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/content-delivery-network
# ✅ content-delivery-network 共抓到 3 篇文章
# 爬取中: https://netflixtechblog.com/tagged/automation-testing
# ✅ automation-testing 共抓到 2 篇文章
# 爬取中: https://netflixtechblog.com/tagged/saas
# ✅ saas 共抓到 2 篇文章
# 爬取中: https://netflixtechblog.com/tagged/automation-tools
# ✅ automation-tools 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/application-security
# ✅ application-security 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/ddos-protection
# ✅ ddos-protection 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/chaps
# ✅ chaps 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/persistence
# ✅ persistence 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/compression
# ✅ compression 共抓到 4 篇文章
# 爬取中: https://netflixtechblog.com/tagged/automated-testing
# ✅ automated-testing 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/visualization
# ✅ visualization 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/edge-engineering
# ✅ edge-engineering 共抓到 4 篇文章
# 爬取中: https://netflixtechblog.com/tagged/film
# ✅ film 共抓到 2 篇文章
# 爬取中: https://netflixtechblog.com/tagged/tv-series
# ✅ tv-series 共抓到 2 篇文章
# 爬取中: https://netflixtechblog.com/tagged/translation
# ✅ translation 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/i18n
# ✅ i18n 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/globalization
# ✅ globalization 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/dfir
# ✅ dfir 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/incident-response
# ✅ incident-response 共抓到 4 篇文章
# 爬取中: https://netflixtechblog.com/tagged/spring
# ✅ spring 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/apache-cassandra
# ✅ apache-cassandra 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/media-document-model
# ✅ media-document-model 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/standards
# ✅ standards 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/redux
# ✅ redux 共抓到 2 篇文章
# 爬取中: https://netflixtechblog.com/tagged/front-end-development
# ✅ front-end-development 共抓到 3 篇文章
# 爬取中: https://netflixtechblog.com/tagged/cache
# ✅ cache 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/trailers
# ✅ trailers 共抓到 2 篇文章
# 爬取中: https://netflixtechblog.com/tagged/eye-tracking
# ✅ eye-tracking 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/slackbot
# ✅ slackbot 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/sharks
# ✅ sharks 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/timeseries
# ✅ timeseries 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/voltron
# ✅ voltron 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/meetings
# ✅ meetings 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/components
# ✅ components 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/reactive
# ✅ reactive 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/reinforcement-learning
# ✅ reinforcement-learning 共抓到 4 篇文章
# 爬取中: https://netflixtechblog.com/tagged/scala
# ✅ scala 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/notebook
# ✅ notebook 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/realtime
# ✅ realtime 共抓到 2 篇文章
# 爬取中: https://netflixtechblog.com/tagged/contextual-bandit
# ✅ contextual-bandit 共抓到 2 篇文章
# 爬取中: https://netflixtechblog.com/tagged/ml-platform
# ✅ ml-platform 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/pub-sub
# ✅ pub-sub 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/change-data-capture
# ✅ change-data-capture 共抓到 2 篇文章
# 爬取中: https://netflixtechblog.com/tagged/event-driven-systems
# ✅ event-driven-systems 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/data-synchronization
# ✅ data-synchronization 共抓到 2 篇文章
# 爬取中: https://netflixtechblog.com/tagged/mysql
# ✅ mysql 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/postgres
# ✅ postgres 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/metrics-and-analytics
# ✅ metrics-and-analytics 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/druid
# ✅ druid 共抓到 3 篇文章
# 爬取中: https://netflixtechblog.com/tagged/crisis-management
# ✅ crisis-management 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/anime
# ✅ anime 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/sre
# ✅ sre 共抓到 2 篇文章
# 爬取中: https://netflixtechblog.com/tagged/incident-management
# ✅ incident-management 共抓到 2 篇文章
# 爬取中: https://netflixtechblog.com/tagged/cloud-networking
# ✅ cloud-networking 共抓到 3 篇文章
# 爬取中: https://netflixtechblog.com/tagged/data-engineering
# ✅ data-engineering 共抓到 10 篇文章
# 爬取中: https://netflixtechblog.com/tagged/cloud-infrastructure
# ✅ cloud-infrastructure 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/visual-effects
# ✅ visual-effects 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/data-infrastructure
# ✅ data-infrastructure 共抓到 2 篇文章
# 爬取中: https://netflixtechblog.com/tagged/backend
# ✅ backend 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/backends-for-frontends
# ✅ backends-for-frontends 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/debugging
# ✅ debugging 共抓到 3 篇文章
# 爬取中: https://netflixtechblog.com/tagged/vmaf
# ✅ vmaf 共抓到 3 篇文章
# 爬取中: https://netflixtechblog.com/tagged/audio
# ✅ audio 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/loudness
# ✅ loudness 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/stakeholder-engagement
# ✅ stakeholder-engagement 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/tooling
# ✅ tooling 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/career-paths
# ✅ career-paths 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/academia
# ✅ academia 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/netfli
# ✅ netfli 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/asynchronous
# ✅ asynchronous 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/workflow-management
# ✅ workflow-management 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/netflix-studio
# ✅ netflix-studio 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/tracing
# ✅ tracing 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/asset-management
# ✅ asset-management 共抓到 2 篇文章
# 爬取中: https://netflixtechblog.com/tagged/cosmos-microservice
# ✅ cosmos-microservice 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/metaflow
# ✅ metaflow 共抓到 2 篇文章
# 爬取中: https://netflixtechblog.com/tagged/gateway
# ✅ gateway 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/antlr
# ✅ antlr 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/medium
# ✅ medium 共抓到 4 篇文章
# 爬取中: https://netflixtechblog.com/tagged/movies
# ✅ movies 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/dataflow
# ✅ dataflow 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/standardization
# ✅ standardization 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/clustering-algorithm
# ✅ clustering-algorithm 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/unsupervised-learning
# ✅ unsupervised-learning 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/scalable-service
# ✅ scalable-service 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/annotations
# ✅ annotations 共抓到 2 篇文章
# 爬取中: https://netflixtechblog.com/tagged/semantic-search
# ✅ semantic-search 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/asset-management-software
# ✅ asset-management-software 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/alerting
# ✅ alerting 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/media-search
# ✅ media-search 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/realtime-video-processing
# ✅ realtime-video-processing 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/flink
# ✅ flink 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/event-streaming
# ✅ event-streaming 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/high-dynamic-range
# ✅ high-dynamic-range 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/conference
# ✅ conference 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/system-design-interview
# ✅ system-design-interview 共抓到 1 篇文章
# 爬取中: https://netflixtechblog.com/tagged/counter
# ✅ counter 共抓到 1 篇文章
# ✅ 完成！共 537 筆文章連結。
